# %%
import pandas as pd                                           
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy.random import randn

## these all are important libaries for data visualisation.

# %%
df = pd.read_excel(r'C:\Users\admin\Downloads\statewise data.xlsx')
df

## phase 1 Data Collection/preparation part.
## Data collected manual through wikipedia.
# Out:
#                 State_UT  Year     Population Literacy_Rate  Area (km square)
# 0          Uttar Pradesh  2011  19,98,12,341          0.697            240928
# 1             Maharastra  2011  11,23,74,333          0.829            307713
# 2                  Bihar  2011  10,40,99,452          0.638             94163
# 3            West Bengal  2011   9,12,76,115          0.771             88752
# 4         Madhya Pradesh  2011   7,26,26,809          0.706            308245
# ..                   ...   ...            ...           ...               ...
# 67                Sikkim  2023         689000        0.8142              7096
# 68  Dadra & Nagar Haveli  2023        1263000        0.7624               603
# 69     Andaman & Nicobar  2023         403000        0.8663              8249
# 70                Ladakh  2023         300000        0.9029            174975
# 71           Lakshadweep  2023          69000        0.9185                32
#
# [72 rows x 5 columns]

# %%
pd.set_option('display.max_rows',74)
df
# Out:
#                 State_UT  Year      Population Literacy_Rate  Area (km square)
# 0          Uttar Pradesh  2011   19,98,12,341          0.697            240928
# 1             Maharastra  2011   11,23,74,333          0.829            307713
# 2                  Bihar  2011   10,40,99,452          0.638             94163
# 3            West Bengal  2011    9,12,76,115          0.771             88752
# 4         Madhya Pradesh  2011    7,26,26,809          0.706            308245
# 5           Tamil Nadu    2011    7,21,47,030          0.803            130635
# 6              Rajasthan  2011    6,85,48,437          0.671            342239
# 7              Karnataka  2011    6,10,95,297          0.756            191792
# 8                Gujarat  2011    6,04,39,692          0.793            196024
# 9         Andhra Pradesh  2011        49386799         0.674            162986
# 10                Odisha  2011   4,19,74,218           0.735            155814
# ...

# %%
##Phase 2
## statewise crimes data import

df = pd.read_excel(r'C:\Users\admin\Downloads\ststewise crime.xlsx')
df
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Sparkline Group extension is not supported and will be removed
#   for idx, row in parser.parse():
#             statewise_ut  year  Rape  property stolen  murder  kidnapping  \
# 0          Uttar Pradesh  2011     2           2013.0    4951        8500
# 1             Maharastra  2011    43         185079.6    2818        1669
# 2                  Bihar  2011     2           5992.2    3198        4268
# 3            West Bengal  2011     7          56648.6    2109        4285
# 4         Madhya Pradesh  2011    10          15144.5    2511        1288
# 5           Tamil Nadu    2011     2          11997.3    1877        1984
# 6              Rajasthan  2011     1          15764.4    1461        3204
# 7              Karnataka  2011     2          20365.3    1820        1395
# 8                Gujarat  2011     2          34979.5    1126        1614
# ...

# %%
## 2.1	Analysis of Literacy rate vs Total crimes

plt.figure(figsize=(10,8))
plt.scatter(df["literacy_rate"], df["Total_crime"], color="red", marker='+')
plt.title("literacy_rate & Total_crime by statewise",fontsize = 20)
plt.xlabel("literacy_rate")
plt.ylabel("Total_crime")
plt.show()

# %%
##2.4	 Analysis of area vs overall crime

plt.figure(figsize=(10,8))
plt.scatter(df["Area"], df["Total_crime"], color="red", marker='+')
plt.title("Area vs Total_crime by statewise",fontsize = 20)
plt.xlabel("Area")
plt.ylabel("Total_crime")
plt.show()

# %%
##2.5	 Analysis of population vs overall crime

plt.figure(figsize=(10,8))
plt.scatter(df["Population"], df["Total_crime"], color="red", marker='+')
plt.title("Population & Total_crime by statewise",fontsize = 20)
plt.xlabel("Total_crime")
plt.ylabel("Population")
plt.show()
